# %% [markdown]
# ## AC Transit GTFS RT
#
# **Links**:
# - [AC Transit API Documentation](https://api.actransit.org/transit/Help)
#
#
# - [OpenMobilityData](https://transitfeeds.com/p/ac-transit/579) has their own API but probably should just go to the source via AC Transit
# - [Urban Access](https://github.com/UDST/urbanaccess) mentioned in class but not sure if what I am looking for
# - how-to on the Python requests library: https://realpython.com/python-requests/
#
#
# - [Using PostgreSQL in Python](https://www.datacamp.com/community/tutorials/tutorial-postgresql-python)
# - Heroku deployment:
#     - http://briancaffey.github.io/2016/04/05/twitter-bot-tutorial.html <-- try setting up this tweetbot first and then can change the code to run AC Transit API....would I even need to push the data to PostgreSQL with this method or could it be stored "on file" on Heroku's server?
#     - https://bigishdata.com/2016/12/15/running-python-background-jobs-with-heroku/
#     - https://www.youtube.com/watch?v=DwWPunpypNA
# - [Python Anywhere](https://www.pythonanywhere.com/) could be another option?
#
#
# **Currently working on**:
# - [x] having trouble calling API, maybe can ask Anson (see: [Quantifying Transit Reliability](https://blog.conveyal.com/quantifying-transit-reliability-using-accessibility-indicators-6b69f5337cd3)) --> [SOLVED] [MobilityData](https://github.com/MobilityData/gtfs-realtime-bindings/tree/master/python) has sample code showing how to use the google.transit package to decode the protocol buffer returned by the API
# - [x] convert feed.entity to pandas df
# - [x] create map (folium?) with locations of current buses
# - [ ] schedule realtime calls, collect data
# - [ ] identify bus bunching
# - [x] create config file with tokens and keys that can be hidden on local machine

# %%
import pandas as pd
import numpy as np
import csv
import json
from datetime import datetime
import requests
from google.transit import gtfs_realtime_pb2

# %%
from config import *
BASE = "https://api.actransit.org/transit/"

# %% [markdown]
# #### Call RT-GTFS

# %%
#response = requests.get(config['BASE']+"gtfsrt/vehicles/?token="+config['KEY'])
#response = requests.get(config['BASE']+"actrealtime/servicebulletin/?token="+config['KEY'])

# %%
feed = gtfs_realtime_pb2.FeedMessage()
response = requests.get(BASE+"gtfsrt/vehicles/?token="+KEY)
feed.ParseFromString(response.content)
# Out:
# 20827

# %%
#feed.entity

# %%
#feed.entity[0].vehicle.trip.route_id
feed.entity[-1]
# Out:
# id: "327"
# vehicle {
#   trip {
#     trip_id: "835834020"
#     schedule_relationship: SCHEDULED
#     route_id: "62"
#   }
#   position {
#     latitude: 37.77540969848633
#     longitude: -122.22554016113281
#     bearing: 311.0
#     speed: 0.0
#   }
#   timestamp: 1582060814
#   vehicle {
#     id: "1449"
#   }
# }

# %%
for entity in feed.entity:
    if entity.vehicle.trip.route_id == "6":
        print(entity.vehicle.trip.trip_id)
# Out:
# 743236020
# 743281020
# 743300020
# 743357020
# 743218020
# 743322020
# 743337020
# 743370020

# %% [markdown]
# #### convert feed.entity to pandas df
#
# this and next section on folium built from: https://georgetsilva.github.io/posts/mapping-points-with-folium/

# %%
route_id = []
trip_id = []
vehicle_id = []
latitude = []
longitude = []
bearing = []
speed = []
unix_time = []
#schedule_relationship = []

for entity in feed.entity:
    route_id.append(entity.vehicle.trip.route_id)
    trip_id.append(entity.vehicle.trip.trip_id)
    vehicle_id.append(entity.vehicle.vehicle.id)
    latitude.append(entity.vehicle.position.latitude)
    longitude.append(entity.vehicle.position.longitude)
    bearing.append(entity.vehicle.position.bearing)
    speed.append(entity.vehicle.position.speed)
    unix_time.append(entity.vehicle.timestamp)

df_busLocations = pd.DataFrame(
    {'route_id' : route_id,
     'trip_id' : trip_id,
     'vehicle_id' : vehicle_id,
     'latitude' : latitude,
     'longitude' : longitude,
     'bearing' : bearing,
     'speed': speed,
     'unix_time': unix_time
    })

df_busLocations['time'] = pd.to_datetime(df_busLocations['unix_time'], unit='s').astype('datetime64[ns, US/Pacific]')

# %%
df_busLocations[df_busLocations.route_id == "80"].head(25)
# Out:
#     route_id    trip_id vehicle_id   latitude   longitude  bearing    speed  \
# 0         80  742472020       5020  37.853138 -122.281914    254.0  5.36448
# 32        80  742431020       5016  37.868359 -122.297806    166.0  0.00000
# 256       80  742471020       5120  37.901131 -122.309242     79.0  9.38784
# 262       80  742430020       5004  37.902874 -122.299194    332.0  3.57632
# 280       80  742432020       5115  37.856735 -122.255119     79.0  8.04672
#
#       unix_time                      time
# 0    1582060824 2020-02-18 13:20:24-08:00
# 32   1582060817 2020-02-18 13:20:17-08:00
# 256  1582060826 2020-02-18 13:20:26-08:00
# 262  1582060816 2020-02-18 13:20:16-08:00
# 280  1582060823 2020-02-18 13:20:23-08:00

# %% [markdown]
# #### use folium to map current bus locations

# %%
import folium

# %%
locations = df_busLocations[['latitude', 'longitude']]
locationlist = locations.values.tolist()

# %%
map = folium.Map(location=[37.8, -122.2], tiles='CartoDB positron', zoom_start=11)
for point in range(0, len(locationlist)):
    folium.Marker(
        locationlist[point], 
        popup=folium.Popup(
            "Route: " + df_busLocations['route_id'][point] + "\n" + 
            "Trip: " + df_busLocations['trip_id'][point]
        )
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### save bus locations (lat, lon) to file

# %%
df_busLocations.to_csv("ACTransit_Veh_Loc.csv")

# %%
df_busLocations.to_csv("ACTransit_Veh_Loc_0219.csv", mode='a', header=False)

# %% [markdown]
# #### loop to call API and save everything to file

# %%
def call_api(BASE, KEY):
    feed = gtfs_realtime_pb2.FeedMessage()
    response = requests.get(BASE+"gtfsrt/vehicles/?token="+KEY)
    feed.ParseFromString(response.content)
    return feed

def api_json_to_csv(feed):
    route_id = []
    trip_id = []
    vehicle_id = []
    latitude = []
    longitude = []
    bearing = []
    speed = []
    unix_time = []
    #schedule_relationship = []

    for entity in feed.entity:
        route_id.append(entity.vehicle.trip.route_id)
        trip_id.append(entity.vehicle.trip.trip_id)
        vehicle_id.append(entity.vehicle.vehicle.id)
        latitude.append(entity.vehicle.position.latitude)
        longitude.append(entity.vehicle.position.longitude)
        bearing.append(entity.vehicle.position.bearing)
        speed.append(entity.vehicle.position.speed)
        unix_time.append(entity.vehicle.timestamp)

    df = pd.DataFrame(
        {'route_id' : route_id,
         'trip_id' : trip_id,
         'vehicle_id' : vehicle_id,
         'latitude' : latitude,
         'longitude' : longitude,
         'bearing' : bearing,
         'speed': speed,
         'unix_time': unix_time
        })

# scheduler to call and save API
# while x < 10:

# %% [markdown]
# #### testing other API Calls

# %% [markdown]
# RouteIds

# %%
response = requests.get(config['BASE']+"routes/?token="+config['KEY'])
routes = response.json()

# %%
route_id = []
name = []
description = []

for i in routes:
    route_id.append(i['RouteId'])
    name.append(i['Name'])
    description.append(i['Description'])

routes_df = pd.DataFrame(
    {'RouteId' : route_id,
     'Name' : name,
     'Description' : description
    })

# %%
routes_df
# Out:
#     RouteId Name                             Description
# 0         1    1                 International - E. 14th
# 1        10   10                   E. 14th St. - Mission
# 2        12   12  Dtn. Oakland\Dtn. Berkeley\ Gilman St.
# 3        14   14         14th St - San Antonio - High St
# 4        18   18             Solano - Shattuck - MLK Jr.
# 5        19   19                 Buena Vista - Fruitvale
# 6        20   20        Dimond - Fruitvale - South Shore
# 7       200  200           Decoto - Newark Blvd. - Mowry
# 8        21   21           Dimond - Fruitvale - Bay Farm
# 9       210  210        Fremont Blvd. - Mission San Jose
# 10      212  212         Fremont Blvd. - Pacific Commons
# 11      215  215         Osgood - Warm Springs - Landing
# 12      216  216             Niles - Stevenson - NewPark
# 13      217  217             Mission San Jose - Milpitas
# 14      232  232              Mission - Decoto - NewPark
# 15      239  239                  Grimmer - Warm Springs
# 16      251  251         Paseo Padre - Thornton - Cherry
# 17       28   28        Alvarado - Castro Valley - B St.
# 18       29   29            Hollis - Peralta - Lakeshore
# 19      314  314                    West Oakland Shopper
# 20       33   33        Piedmont - Harrison - Park Blvd.
# 21      339  339         Chabot Space and Science Center
# 22       34   34            Estudillo - Davis - Meekland
# 23       35   35          Estudillo - Davis -  Lewelling
# 24      356  356                    East Oakland Shopper
# 25       36   36           Dwight - Shellmound - Adeline
# 26      376  376         Cutting - North Richmond Nights
# 27       39   39            Skyline - Dimond - Fruitvale
# 28      399  399                        SUPERVISOR ORDER
# 29       40   40          Foothill - Bancroft - Bay Fair
# ..      ...  ...                                     ...
# 128     BF3  BF3           San Francisco - Richmond (D3)
# 129     BSD  BSD                    BROADWAY SHUTTLE DAY
# 130     BSN  BSN                  BROADWAY SHUTTLE NIGHT
# 131       C    C            Piedmont - 40th St. Transbay
# 132      CB   CB               Broadway Terrace Transbay
# 133       E    E         Tunnel Rd. - Claremont Transbay
# 134       F    F               Adeline - Market Transbay
# 135      FS   FS          Shattuck - University Transbay
# 136       G    G                Colusa - Solano Transbay
# 137       H    H             Arlington - Gilman Transbay
# 138       J    J         Sacramento -  Christie Transbay
# 139       L    L                      San Pablo Transbay
# 140      LA   LA               Hilltop - Pierce Transbay
# 141       M    M               San Mateo Bridge - Winton
# 142      NL   NL              MacArthur Transbay Limited
# 143      NX   NX           Grand Lake - Laurel  Transbay
# 144     NX1  NX1         MacArthur - Grand Lake Transbay
# 145     NX2  NX2             MacArthur - Laurel Transbay
# 146     NX3  NX3           MacArthur - Eastmont Transbay
# 147     NX4  NX4                  Castro Valley Transbay
# 148     NXC  NXC         MacArthur - Castro Vly Transbay
# 149       O    O          Santa Clara - Encinal Transbay
# 150      OX   OX            Bay Farm - Park St. Transbay
# 151       P    P        Piedmont - Oakland Ave. Transbay
# 152       S    S               Washington Manor Transbay
# 153      SB   SB            Newark - Union City Transbay
# 154       U    U          Stanford - Dumbarton - Fremont
# 155       V    V         Montclair - Park Blvd. Transbay
# 156       W    W             High - South Shore Transbay
# 157       Z    Z             6th St. - Christie Transbay
#
# [158 rows x 3 columns]

# %% [markdown]
# route directions

# %%
route_names = routes_df['Name']
directions = []
for i in route_names:
    response = requests.get(config['BASE']+"route/"+i+"/directions?token="+config['KEY'])
    dir_response = response.json()
    directions.append(dir_response)

routes_df['Directions'] = directions

# %%
routes_df.head()
# Out:
#   RouteId Name                             Description  \
# 0       1    1                 International - E. 14th
# 1      10   10                   E. 14th St. - Mission
# 2      12   12  Dtn. Oakland\Dtn. Berkeley\ Gilman St.
# 3      14   14         14th St - San Antonio - High St
# 4      18   18             Solano - Shattuck - MLK Jr.
#
#                                Directions
# 0  [NORTH, Northbound, SOUTH, Southbound]
# 1                [Northbound, Southbound]
# 2  [NORTH, Northbound, SOUTH, Southbound]
# 3      [EAST, Eastbound, WEST, Westbound]
# 4  [NORTH, Northbound, SOUTH, Southbound]

# %%
unique_dir = []
for i in directions:
    for j in i:
        if j not in unique_dir:
            unique_dir.append(j)
unique_dir
# Out:
# ['NORTH',
#  'Northbound',
#  'SOUTH',
#  'Southbound',
#  'EAST',
#  'Eastbound',
#  'WEST',
#  'Westbound',
#  'Clockwise',
#  'CW',
#  '1',
#  'DIR1',
#  'Outbound',
#  'CCW',
#  'Counterclock']

# %% [markdown]
# loop to get route and directions in long format database

# %%
# get routes from API
response = requests.get(config['BASE']+"routes/?token="+config['KEY'])
routes = response.json()

# initialize empty arrays for database
route_id = []
name = []
description = []
direction = []

# loop through routes
for i in routes:
    # get directions per route from API
    print("Now processing:{}".format(i['RouteId']))
    response = requests.get(config['BASE']+"route/"+i['RouteId']+"/directions?token="+config['KEY'])
    dir_response = response.json()
    
    # loop through directions
    for j in dir_response:
        route_id.append(i['RouteId'])
        name.append(i['Name'])
        description.append(i['Description'])
        direction.append(j)
    #end for j
#end for i

routes_dir_df = pd.DataFrame(
    {'RouteId': route_id,
     'Name': name,
     'Description': description,
     'Direction': direction
    })
# Out:
# Now processing:1
# Now processing:10
# Now processing:12
# Now processing:14
# Now processing:18
# Now processing:19
# Now processing:20
# Now processing:200
# Now processing:21
# Now processing:210
# Now processing:212
# Now processing:215
# Now processing:216
# Now processing:217
# Now processing:232
# Now processing:239
# Now processing:251
# Now processing:28
# Now processing:29
# Now processing:314
# Now processing:33
# Now processing:339
# Now processing:34
# Now processing:35
# Now processing:356
# Now processing:36
# Now processing:376
# Now processing:39
# Now processing:399
# Now processing:40
# Now processing:41
# Now processing:448
# Now processing:45
# Now processing:46
# Now processing:46L
# Now processing:47
# Now processing:475
# Now processing:51A
# Now processing:51B
# Now processing:52
# Now processing:54
# Now processing:56
# Now processing:57
# Now processing:6
# Now processing:60
# Now processing:604
# Now processing:605
# Now processing:606
# Now processing:607
# Now processing:611
# Now processing:617
# Now processing:62
# Now processing:620
# Now processing:621
# Now processing:623
# Now processing:624
# Now processing:625
# Now processing:626
# Now processing:628
# Now processing:629
# Now processing:631
# Now processing:638
# Now processing:642
# Now processing:646
# Now processing:648
# Now processing:649
# Now processing:65
# Now processing:650
# Now processing:652
# Now processing:653
# Now processing:654
# Now processing:655
# Now processing:657
# Now processing:658
# Now processing:660
# Now processing:662
# Now processing:663
# Now processing:667
# Now processing:668
# Now processing:669
# Now processing:67
# Now processing:671
# Now processing:672
# Now processing:675
# Now processing:676
# Now processing:677
# Now processing:679
# Now processing:680
# Now processing:681
# Now processing:682
# Now processing:684
# Now processing:687
# Now processing:688
# Now processing:696
# Now processing:7
# Now processing:70
# Now processing:701
# Now processing:702
# Now processing:703
# Now processing:706
# Now processing:707
# Now processing:71
# Now processing:72
# Now processing:72M
# Now processing:72R
# Now processing:73
# Now processing:74
# Now processing:76
# Now processing:79
# Now processing:80
# Now processing:800
# Now processing:801
# Now processing:802
# Now processing:805
# Now processing:83
# Now processing:840
# Now processing:851
# Now processing:86
# Now processing:88
# Now processing:90
# Now processing:93
# Now processing:94
# Now processing:95
# Now processing:96
# Now processing:97
# Now processing:98
# Now processing:99
# Now processing:B
# Now processing:BF3
# Now processing:BSD
# Now processing:BSN
# Now processing:C
# Now processing:CB
# Now processing:E
# Now processing:F
# Now processing:FS
# Now processing:G
# Now processing:H
# Now processing:J
# Now processing:L
# Now processing:LA
# Now processing:M
# Now processing:NL
# Now processing:NX
# Now processing:NX1
# Now processing:NX2
# Now processing:NX3
# Now processing:NX4
# Now processing:NXC
# Now processing:O
# Now processing:OX
# Now processing:P
# Now processing:S
# Now processing:SB
# Now processing:U
# Now processing:V
# Now processing:W
# Now processing:Z

# %%
routes_dir_df.head(10)
# Out:
#   RouteId Name                             Description   Direction
# 0       1    1                 International - E. 14th       NORTH
# 1       1    1                 International - E. 14th  Northbound
# 2       1    1                 International - E. 14th       SOUTH
# 3       1    1                 International - E. 14th  Southbound
# 4      10   10                   E. 14th St. - Mission  Northbound
# 5      10   10                   E. 14th St. - Mission  Southbound
# 6      12   12  Dtn. Oakland\Dtn. Berkeley\ Gilman St.       NORTH
# 7      12   12  Dtn. Oakland\Dtn. Berkeley\ Gilman St.  Northbound
# 8      12   12  Dtn. Oakland\Dtn. Berkeley\ Gilman St.       SOUTH
# 9      12   12  Dtn. Oakland\Dtn. Berkeley\ Gilman St.  Southbound

# %% [markdown]
# vehicles
# - appears to get real time location of all vehicles on a specific route

# %%
#route/{routeName}/vehicles
response = requests.get(config['BASE'] + "route/6/vehicles?token="+config['KEY'])
vehicles = response.json()

# %%
map = folium.Map(location=[37.8, -122.2], tiles='CartoDB positron', zoom_start=11)
for veh in vehicles:
    folium.Marker(
        [veh['Latitude'], veh['Longitude']], 
        popup=folium.Popup(
            "Vehicle: " + str(veh['VehicleId']) + "\n" + 
            "Trip: " + str(veh['CurrentTripId']) + "\n" + 
            "Heading: " + str(veh['Heading'])
        )
    ).add_to(map)
map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-6062a6121609> in <module>
# ----> 1 map = folium.Map(location=[37.8, -122.2], tiles='CartoDB positron', zoom_start=11)
#       2 for veh in vehicles:
#       3     folium.Marker(
#       4         [veh['Latitude'], veh['Longitude']],
#       5         popup=folium.Popup(
#
# NameError: name 'folium' is not defined

# %% [markdown]
# trips

# %%
#route/{routeName}/trips?direction={direction}&scheduleType={scheduleType}
response = requests.get(config['BASE'] + "route/6/trips?direction=Northbound&scheduleType=Weekday?token="+config['KEY'])
data = response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-32-91719e0378b3> in <module>
#       1 #route/{routeName}/trips?direction={direction}&scheduleType={scheduleType}
#       2 response = requests.get(config['BASE'] + "route/6/trips?direction=Northbound&scheduleType=Weekday?token="+config['KEY'])
# ----> 3 data = response.json()
#
# ~\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
response
# Out:
# <Response [401]>

# %% [markdown]
# Realtime Information

# %%
df_busLocations[df_busLocations.route_id == "6"]
# Out:
#     route_id    trip_id vehicle_id   latitude   longitude  bearing    speed
# 9          6  743357020       1580  37.850712 -122.260452    187.0  0.00000
# 36         6  743236020       1218  37.814091 -122.268356     13.0  0.00000
# 50         6  743218020       1350  37.801842 -122.273636    298.0  0.00000
# 54         6  743322020       1347  37.867065 -122.258842    349.0  7.15264
# 64         6  743281020       1343  37.802265 -122.270958     21.0  1.34112
# 83         6  743300020       1357  37.872200 -122.268295    260.0  0.00000
# 86         6  743370020       1353  37.845360 -122.261101    358.0  5.81152
# 268        6  743256020       1553  37.815857 -122.268143    194.0  0.00000
# 304        6  743337020       1202  37.871342 -122.265816    355.0  0.00000

# %%
#response = requests.get(config['BASE'] + "route/6/trip/743281020/stops&token="+config['KEY'])
#response = requests.get(config['BASE'] + "route/6/trip/743281020/stops&token="+config['KEY'])
#response = requests.get(config['BASE'] + "route/6/directions?token="+config['KEY'])
#response = requests.get(config['BASE'] + "route/6?token="+config['KEY'])

# %%
#response = requests.get(config['BASE'] + "actrealtime/line?callback=jsonp&token=" + config['KEY'])
response = requests.get(config['BASE'] + "stops?token=" + config['KEY'])

# %%
stops = response.json()

# %%
#GET actrealtime/stop?rt={rt}&dir={dir}&stpid={stpid}&callback={callback}
routes_dir_6_df = routes_dir_df[routes_dir_df.RouteId == "6"]
for row, idx in routes_dir_6_df.iter():
    rt = row['RouteId']
    dr = row['Direction']
    response = requests.get(config['BASE'] + "actrealtime/stop?rt="+rt+"&dir="+dr+"&token=" + config['KEY'])
    next_stops = response.json()
    print(next_stops)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-985f2e614054> in <module>
#       1 #GET actrealtime/stop?rt={rt}&dir={dir}&stpid={stpid}&callback={callback}
#       2 routes_dir_6_df = routes_dir_df[routes_dir_df.RouteId == "6"]
# ----> 3 for row, idx in routes_dir_6_df.iter():
#       4     rt = row['RouteId']
#       5     dr = row['Direction']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5271             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5272                 return self[name]
# -> 5273             return object.__getattribute__(self, name)
#    5274
#    5275     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iter'

# %%
next_stops
# Out:
# {'bustime-response': {'error': [{'rtpidatafeed': 'bustime',
#     'rt': '10',
#     'dir': 'Northbound',
#     'msg': 'No data found for parameter'}]}}

# %%
#GET actrealtime/direction?rt={rt}&callback={callback}
response = requests.get(config['BASE'] + "actrealtime/direction?rt=6&token="+config['KEY'])
if response:
    print('Success!') 
    data = response.json()
else:
    print('An error has occurred.')
    print(response.headers)
    print(response.content)
# Out:
# Success!

# %%
stops[:5]
# Out:
# [{'StopId': 52246,
#   'Name': '8th St:Portola Av',
#   'Latitude': 37.7688136,
#   'Longitude': -122.2729918,
#   'ScheduledTime': None},
#  {'StopId': 57793,
#   'Name': '8th St:Portola Av',
#   'Latitude': 37.7689929,
#   'Longitude': -122.2727976,
#   'ScheduledTime': None},
#  {'StopId': 56707,
#   'Name': '1105 Atlantic Av',
#   'Latitude': 37.7802724,
#   'Longitude': -122.2640149,
#   'ScheduledTime': None},
#  {'StopId': 57796,
#   'Name': 'Atlantic Av:Challenger Dr',
#   'Latitude': 37.7810663,
#   'Longitude': -122.2700596,
#   'ScheduledTime': None},
#  {'StopId': 54332,
#   'Name': 'Atlantic Av:Triumph Dr',
#   'Latitude': 37.780799,
#   'Longitude': -122.266125,
#   'ScheduledTime': None}]

# %% [markdown]
# #### get route-specific patterns
#
# https://api.actransit.org/transit/Help/Api/GET-actrealtime-pattern_pid_rt_callback

# %%
# GET actrealtime/pattern?pid={pid}&rt={rt}&callback={callback}
response = requests.get(config['BASE'] + "actrealtime/pattern?rt=6&token="+config['KEY'])
if response:
    print('Success!') 
    patterns = response.json()
else:
    print('An error has occurred.')
    print(response.headers)
    print(response.content)
# Out:
# Success!

# %%
patterns['bustime-response']['ptr'][0]
# Out:
# {'pid': 5535,
#  'ln': 31559.0,
#  'rtdir': 'To Downtown Oakland',
#  'pt': [{'seq': 1,
#    'lat': 37.871341985008,
#    'lon': -122.265813,
#    'typ': 'S',
#    'stpid': '51705',
#    'stpnm': 'Oxford St:Addison St',
#    'pdist': 0.0},
#   {'seq': 2, 'lat': 37.871653, 'lon': -122.265911, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 3, 'lat': 37.872485, 'lon': -122.266001, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 4, 'lat': 37.872185, 'lon': -122.268407, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 5, 'lat': 37.870808, 'lon': -122.268254, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 6, 'lat': 37.870565, 'lon': -122.268187, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 7, 'lat': 37.87015, 'lon': -122.267976, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 8, 'lat': 37.869762, 'lon': -122.267993, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 9, 'lat': 37.869593, 'lon': -122.268073, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 10,
#    'lat': 37.869479985142,
#    'lon': -122.268127000002,
#    'typ': 'S',
#    'stpid': '55555',
#    'stpnm': 'Shattuck Av:Allston Way',
#    'pdist': 2143.0},
#   {'seq': 11, 'lat': 37.86913, 'lon': -122.268021, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 12, 'lat': 37.868349, 'lon': -122.267973, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 13,
#    'lat': 37.868191985236,
#    'lon': -122.267990000002,
#    'typ': 'S',
#    'stpid': '55999',
#    'stpnm': 'Shattuck Av + Kittredge St',
#    'pdist': 2620.0},
#   {'seq': 14, 'lat': 37.867878, 'lon': -122.267886, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 15, 'lat': 37.866684, 'lon': -122.267743, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 16, 'lat': 37.866698, 'lon': -122.267386, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 17,
#    'lat': 37.866694985344,
#    'lon': -122.267150999999,
#    'typ': 'S',
#    'stpid': '51835',
#    'stpnm': 'Durant Av:Shattuck Av',
#    'pdist': 3351.0},
#   {'seq': 18, 'lat': 37.86681, 'lon': -122.266719, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 19, 'lat': 37.86721, 'lon': -122.263617, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 20, 'lat': 37.867205, 'lon': -122.263389, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 21,
#    'lat': 37.867200985307,
#    'lon': -122.263217000002,
#    'typ': 'S',
#    'stpid': '51584',
#    'stpnm': 'Durant Av + Ellsworth St',
#    'pdist': 4509.0},
#   {'seq': 22, 'lat': 37.867317, 'lon': -122.262786, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 23, 'lat': 37.867431, 'lon': -122.261908, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 24, 'lat': 37.867423, 'lon': -122.261453, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 25,
#    'lat': 37.867421985292,
#    'lon': -122.261415999999,
#    'typ': 'S',
#    'stpid': '57555',
#    'stpnm': 'Durant Av + Dana St',
#    'pdist': 5041.0},
#   {'seq': 26, 'lat': 37.867158, 'lon': -122.261194, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 27, 'lat': 37.866093, 'lon': -122.260975, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 28, 'lat': 37.865913, 'lon': -122.260987, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 29,
#    'lat': 37.865814985408,
#    'lon': -122.260992999999,
#    'typ': 'S',
#    'stpid': '55138',
#    'stpnm': 'Dana St + Haste St',
#    'pdist': 5655.0},
#   {'seq': 30, 'lat': 37.865551, 'lon': -122.260867, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 31, 'lat': 37.864841, 'lon': -122.260722, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 32, 'lat': 37.86506, 'lon': -122.258939, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 33, 'lat': 37.86499, 'lon': -122.258721, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 34, 'lat': 37.864832, 'lon': -122.258578, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 35, 'lat': 37.864653, 'lon': -122.258602, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 36,
#    'lat': 37.864506985501,
#    'lon': -122.258621000001,
#    'typ': 'S',
#    'stpid': '51555',
#    'stpnm': 'Telegraph Av + Dwight Way',
#    'pdist': 6804.0},
#   {'seq': 37, 'lat': 37.864183, 'lon': -122.258614, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 38, 'lat': 37.86328, 'lon': -122.258738, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 39, 'lat': 37.862937, 'lon': -122.258874, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 40,
#    'lat': 37.862916985618,
#    'lon': -122.258881999999,
#    'typ': 'S',
#    'stpid': '58835',
#    'stpnm': 'Telegraph Av + Parker St',
#    'pdist': 7396.0},
#   {'seq': 41, 'lat': 37.862559, 'lon': -122.258839, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 42, 'lat': 37.861493, 'lon': -122.258989, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 43, 'lat': 37.861322, 'lon': -122.259059, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 44,
#    'lat': 37.861156985743,
#    'lon': -122.259126,
#    'typ': 'S',
#    'stpid': '59593',
#    'stpnm': 'Telegraph Av + Derby St',
#    'pdist': 8051.0},
#   {'seq': 45, 'lat': 37.860799, 'lon': -122.259086, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 46, 'lat': 37.860072, 'lon': -122.259183, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 47, 'lat': 37.85973, 'lon': -122.259325, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 48,
#    'lat': 37.859712985847,
#    'lon': -122.259331999999,
#    'typ': 'S',
#    'stpid': '51215',
#    'stpnm': 'Telegraph Av + Stuart St',
#    'pdist': 8590.0},
#   {'seq': 49, 'lat': 37.859355, 'lon': -122.259287, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 50, 'lat': 37.858203, 'lon': -122.259442, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 51, 'lat': 37.857857, 'lon': -122.259565, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 52,
#    'lat': 37.857788985987,
#    'lon': -122.259588999999,
#    'typ': 'S',
#    'stpid': '58330',
#    'stpnm': 'Telegraph Av + Russell St',
#    'pdist': 9304.0},
#   {'seq': 53, 'lat': 37.857482, 'lon': -122.259544, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 54, 'lat': 37.856767, 'lon': -122.259644, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 55, 'lat': 37.856423, 'lon': -122.25978, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 56,
#    'lat': 37.856404986087,
#    'lon': -122.259786999999,
#    'typ': 'S',
#    'stpid': '57088',
#    'stpnm': 'Telegraph Av + Ashby Av',
#    'pdist': 9820.0},
#   {'seq': 57, 'lat': 37.856046, 'lon': -122.259752, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 58, 'lat': 37.855689, 'lon': -122.259803, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 59, 'lat': 37.855342, 'lon': -122.259924, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 60,
#    'lat': 37.855314986167,
#    'lon': -122.259933999998,
#    'typ': 'S',
#    'stpid': '55529',
#    'stpnm': 'Telegraph Av + Webster St',
#    'pdist': 10226.0},
#   {'seq': 61, 'lat': 37.855003, 'lon': -122.259902, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 62, 'lat': 37.85291, 'lon': -122.260181, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 63, 'lat': 37.852823, 'lon': -122.260149, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 64, 'lat': 37.850728, 'lon': -122.260443, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 65, 'lat': 37.850396, 'lon': -122.260619, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 66,
#    'lat': 37.850385986521,
#    'lon': -122.260625,
#    'typ': 'S',
#    'stpid': '53377',
#    'stpnm': 'Telegraph Av + Alcatraz Av',
#    'pdist': 12055.0},
#   {'seq': 67, 'lat': 37.850032, 'lon': -122.260541, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 68, 'lat': 37.848374, 'lon': -122.260767, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 69, 'lat': 37.84821, 'lon': -122.26086, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 70,
#    'lat': 37.848039986691,
#    'lon': -122.260955999999,
#    'typ': 'S',
#    'stpid': '51123',
#    'stpnm': 'Telegraph Av + 62nd St',
#    'pdist': 12932.0},
#   {'seq': 71, 'lat': 37.847783, 'lon': -122.260849, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 72, 'lat': 37.846889, 'lon': -122.260972, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 73, 'lat': 37.846724, 'lon': -122.261063, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 74,
#    'lat': 37.846579986799,
#    'lon': -122.261142,
#    'typ': 'S',
#    'stpid': '50422',
#    'stpnm': 'Telegraph Av + 60th St',
#    'pdist': 13484.0},
#   {'seq': 75, 'lat': 37.846141, 'lon': -122.261078, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 76, 'lat': 37.845068, 'lon': -122.261227, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 77, 'lat': 37.844904, 'lon': -122.261321, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 78,
#    'lat': 37.84475098693,
#    'lon': -122.261409,
#    'typ': 'S',
#    'stpid': '54499',
#    'stpnm': 'Telegraph Av + 59th St',
#    'pdist': 14169.0},
#   {'seq': 79, 'lat': 37.844398, 'lon': -122.261321, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 80, 'lat': 37.843831, 'lon': -122.261394, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 81, 'lat': 37.843668, 'lon': -122.261491, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 82,
#    'lat': 37.84352198702,
#    'lon': -122.261578999999,
#    'typ': 'S',
#    'stpid': '56007',
#    'stpnm': 'Telegraph Av + 58th St',
#    'pdist': 14634.0},
#   {'seq': 83, 'lat': 37.843221, 'lon': -122.261479, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 84, 'lat': 37.842364, 'lon': -122.261603, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 85, 'lat': 37.842053, 'lon': -122.261743, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 86,
#    'lat': 37.841909987136,
#    'lon': -122.261806,
#    'typ': 'S',
#    'stpid': '55139',
#    'stpnm': 'Telegraph Av + Aileen St',
#    'pdist': 15242.0},
#   {'seq': 87, 'lat': 37.841603, 'lon': -122.261775, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 88, 'lat': 37.840689, 'lon': -122.261886, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 89, 'lat': 37.840517, 'lon': -122.261954, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 90,
#    'lat': 37.840355987249,
#    'lon': -122.262017000001,
#    'typ': 'S',
#    'stpid': '51851',
#    'stpnm': 'Telegraph Av + 55th St',
#    'pdist': 15817.0},
#   {'seq': 91, 'lat': 37.840016, 'lon': -122.261922, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 92, 'lat': 37.838464, 'lon': -122.262137, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 93, 'lat': 37.838305, 'lon': -122.262243, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 94,
#    'lat': 37.838188987406,
#    'lon': -122.262318999998,
#    'typ': 'S',
#    'stpid': '55425',
#    'stpnm': 'Telegraph Av + 52nd St',
#    'pdist': 16631.0},
#   {'seq': 95, 'lat': 37.837836, 'lon': -122.26223, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 96, 'lat': 37.836781, 'lon': -122.262392, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 97, 'lat': 37.836635, 'lon': -122.262525, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 98,
#    'lat': 37.836545987524,
#    'lon': -122.262606999999,
#    'typ': 'S',
#    'stpid': '54111',
#    'stpnm': 'Telegraph Av + 50th St',
#    'pdist': 17257.0},
#   {'seq': 99, 'lat': 37.836242, 'lon': -122.262544, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 100, 'lat': 37.833949, 'lon': -122.263159, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 101, 'lat': 37.833859, 'lon': -122.263263, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 102, 'lat': 37.833428, 'lon': -122.263424, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 103,
#    'lat': 37.833274987761,
#    'lon': -122.263496,
#    'typ': 'S',
#    'stpid': '55989',
#    'stpnm': 'Telegraph Av + 45th St',
#    'pdist': 18498.0},
#   {'seq': 104, 'lat': 37.83275, 'lon': -122.263466, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 105, 'lat': 37.832437, 'lon': -122.263691, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 106,
#    'lat': 37.832370987828,
#    'lon': -122.263737999999,
#    'typ': 'S',
#    'stpid': '56783',
#    'stpnm': 'Telegraph Av + 44th St',
#    'pdist': 18852.0},
#   {'seq': 107, 'lat': 37.832108, 'lon': -122.263643, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 108, 'lat': 37.829777, 'lon': -122.264278, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 109, 'lat': 37.829626, 'lon': -122.264402, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 110,
#    'lat': 37.829497988036,
#    'lon': -122.264507000001,
#    'typ': 'S',
#    'stpid': '55575',
#    'stpnm': 'Telegraph Av + 40th St',
#    'pdist': 19948.0},
#   {'seq': 111, 'lat': 37.829199, 'lon': -122.264432, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 112, 'lat': 37.827045, 'lon': -122.265022, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 113, 'lat': 37.826892, 'lon': -122.26514, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 114,
#    'lat': 37.826739988235,
#    'lon': -122.265256999999,
#    'typ': 'S',
#    'stpid': '55933',
#    'stpnm': 'Telegraph Av + W MacArthur Blvd',
#    'pdist': 20998.0},
#   {'seq': 115, 'lat': 37.826441, 'lon': -122.265173, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 116, 'lat': 37.824895, 'lon': -122.265593, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 117, 'lat': 37.824742, 'lon': -122.265713, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 118,
#    'lat': 37.824593988394,
#    'lon': -122.265829999999,
#    'typ': 'S',
#    'stpid': '54404',
#    'stpnm': 'Telegraph Av + 36th St',
#    'pdist': 21818.0},
#   {'seq': 119, 'lat': 37.824236, 'lon': -122.265782, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 120, 'lat': 37.822848, 'lon': -122.266147, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 121, 'lat': 37.822701, 'lon': -122.266279, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 122,
#    'lat': 37.822612988536,
#    'lon': -122.266357999999,
#    'typ': 'S',
#    'stpid': '54334',
#    'stpnm': 'Telegraph Av + 34th St',
#    'pdist': 22575.0},
#   {'seq': 123, 'lat': 37.822288, 'lon': -122.266297, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 124, 'lat': 37.821344, 'lon': -122.266551, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 125, 'lat': 37.821191, 'lon': -122.26667, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 126,
#    'lat': 37.821038988649,
#    'lon': -122.266787999999,
#    'typ': 'S',
#    'stpid': '50411',
#    'stpnm': 'Telegraph Av + 32nd St',
#    'pdist': 23178.0},
#   {'seq': 127, 'lat': 37.82075, 'lon': -122.26671, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 128, 'lat': 37.819469, 'lon': -122.267055, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 129, 'lat': 37.819316, 'lon': -122.267174, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 130,
#    'lat': 37.819165988788,
#    'lon': -122.267290999999,
#    'typ': 'S',
#    'stpid': '55520',
#    'stpnm': 'Telegraph Av + 30th St',
#    'pdist': 23896.0},
#   {'seq': 131, 'lat': 37.818879, 'lon': -122.267214, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 132, 'lat': 37.816175, 'lon': -122.267911, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 133, 'lat': 37.81597, 'lon': -122.26805, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 134,
#    'lat': 37.815856989026,
#    'lon': -122.268138999998,
#    'typ': 'S',
#    'stpid': '51635',
#    'stpnm': 'Telegragh Av:27th St',
#    'pdist': 25148.0},
#   {'seq': 135, 'lat': 37.8155, 'lon': -122.268088, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 136, 'lat': 37.81347, 'lon': -122.268584, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 137, 'lat': 37.813327, 'lon': -122.268722, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 138,
#    'lat': 37.813246989218,
#    'lon': -122.268798999999,
#    'typ': 'S',
#    'stpid': '52220',
#    'stpnm': 'Telegraph Av + 24th St',
#    'pdist': 26139.0},
#   {'seq': 139, 'lat': 37.812942, 'lon': -122.268717, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 140, 'lat': 37.809567, 'lon': -122.269565, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 141, 'lat': 37.809404, 'lon': -122.269081, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 142, 'lat': 37.809113, 'lon': -122.268814, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 143,
#    'lat': 37.80909798952,
#    'lon': -122.268801000001,
#    'typ': 'S',
#    'stpid': '55777',
#    'stpnm': 'Thomas L Berkley Way  + Telegraph Av',
#    'pdist': 27804.0},
#   {'seq': 144, 'lat': 37.809124, 'lon': -122.268398, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 145, 'lat': 37.809029, 'lon': -122.268221, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 146, 'lat': 37.806652, 'lon': -122.269721, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 147, 'lat': 37.806379, 'lon': -122.270018, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 148,
#    'lat': 37.806322989722,
#    'lon': -122.270077999998,
#    'typ': 'S',
#    'stpid': '50958',
#    'stpnm': 'Broadway + 17th St',
#    'pdist': 29117.0},
#   {'seq': 149, 'lat': 37.805905, 'lon': -122.270178, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 150, 'lat': 37.805159, 'lon': -122.270694, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 151, 'lat': 37.805043, 'lon': -122.270715, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 152, 'lat': 37.803208, 'lon': -122.271938, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 153,
#    'lat': 37.803050989961,
#    'lon': -122.272065,
#    'typ': 'S',
#    'stpid': '50212',
#    'stpnm': 'Broadway + 12th St',
#    'pdist': 30459.0},
#   {'seq': 154, 'lat': 37.802554, 'lon': -122.272298, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 155, 'lat': 37.802484, 'lon': -122.272427, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 156, 'lat': 37.8016, 'lon': -122.272954, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 157, 'lat': 37.802028, 'lon': -122.274156, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 158, 'lat': 37.802152, 'lon': -122.274321, 'typ': 'W', 'pdist': 0.0},
#   {'seq': 159,
#    'lat': 37.802253990018,
#    'lon': -122.274456,
#    'typ': 'S',
#    'stpid': '51636',
#    'stpnm': '10th St:Washington St',
#    'pdist': 31559.0}]}

# %%
for i in patterns['bustime-response']['ptr']:
    print("")
    print(i['rtdir'])
    for j in i['pt']:
        try:
            if j['stpid']:
                latlon = (j['lat'], j['lon'])
                print(j['stpnm'], latlon)
        except KeyError:
            continue
# Out:
# To Downtown Oakland
# Oxford St:Addison St (37.871341985008, -122.265813)
# Shattuck Av:Allston Way (37.869479985142, -122.268127000002)
# Shattuck Av + Kittredge St (37.868191985236, -122.267990000002)
# Durant Av:Shattuck Av (37.866694985344, -122.267150999999)
# Durant Av + Ellsworth St (37.867200985307, -122.263217000002)
# Durant Av + Dana St (37.867421985292, -122.261415999999)
# Dana St + Haste St (37.865814985408, -122.260992999999)
# Telegraph Av + Dwight Way (37.864506985501, -122.258621000001)
# Telegraph Av + Parker St (37.862916985618, -122.258881999999)
# Telegraph Av + Derby St (37.861156985743, -122.259126)
# Telegraph Av + Stuart St (37.859712985847, -122.259331999999)
# Telegraph Av + Russell St (37.857788985987, -122.259588999999)
# Telegraph Av + Ashby Av (37.856404986087, -122.259786999999)
# Telegraph Av + Webster St (37.855314986167, -122.259933999998)
# Telegraph Av + Alcatraz Av (37.850385986521, -122.260625)
# Telegraph Av + 62nd St (37.848039986691, -122.260955999999)
# Telegraph Av + 60th St (37.846579986799, -122.261142)
# Telegraph Av + 59th St (37.84475098693, -122.261409)
# Telegraph Av + 58th St (37.84352198702, -122.261578999999)
# Telegraph Av + Aileen St (37.841909987136, -122.261806)
# Telegraph Av + 55th St (37.840355987249, -122.262017000001)
# Telegraph Av + 52nd St (37.838188987406, -122.262318999998)
# Telegraph Av + 50th St (37.836545987524, -122.262606999999)
# Telegraph Av + 45th St (37.833274987761, -122.263496)
# Telegraph Av + 44th St (37.832370987828, -122.263737999999)
# Telegraph Av + 40th St (37.829497988036, -122.264507000001)
# Telegraph Av + W MacArthur Blvd (37.826739988235, -122.265256999999)
# Telegraph Av + 36th St (37.824593988394, -122.265829999999)
# Telegraph Av + 34th St (37.822612988536, -122.266357999999)
# Telegraph Av + 32nd St (37.821038988649, -122.266787999999)
# Telegraph Av + 30th St (37.819165988788, -122.267290999999)
# Telegragh Av:27th St (37.815856989026, -122.268138999998)
# Telegraph Av + 24th St (37.813246989218, -122.268798999999)
# Thomas L Berkley Way  + Telegraph Av (37.80909798952, -122.268801000001)
# Broadway + 17th St (37.806322989722, -122.270077999998)
# Broadway + 12th St (37.803050989961, -122.272065)
# 10th St:Washington St (37.802253990018, -122.274456)
#
# To Downtown Berkeley
# 10th St:Washington St (37.802253990018, -122.274456)
# 11th St + Clay St (37.802962989968, -122.274464000001)
# Franklin St:14th St (37.804102989883, -122.269714)
# Thomas L Berkley Way  + Telegraph Av (37.809586989483, -122.269413000002)
# Telegraph Av + 24th St (37.814090989155, -122.268358)
# Telegragh Av:27th St (37.816533988978, -122.267705000001)
# Telegraph Av + 29th St (37.818048988867, -122.267335000001)
# Telegraph Av + 31st St (37.820312988703, -122.266710999999)
# Telegraph Av + 34th St (37.822287988559, -122.266189999998)
# Telegraph Av + 36th St (37.824371988408, -122.265627000001)
# Telegraph Av + 38th St (37.826878988226, -122.264958999999)
# Telegraph Av + 40th St (37.829489988037, -122.264214999999)
# Telegraph Av + 43rd St (37.831829987867, -122.263630000002)
# Telegraph Av + 46th St (37.833569987741, -122.263148999999)
# Telegraph Av:49th St (37.835874987575, -122.262539999999)
# Telegraph Av + Claremont Av (37.838460987386, -122.262032)
# Telegraph Av + 55th St (37.840046987272, -122.261812999998)
# Telegraph Av + Aileen St (37.841687987153, -122.261571999999)
# Telegraph Av + 59th St. (37.845283986893, -122.261084000001)
# Telegraph Av + 62nd St (37.847859986706, -122.260719)
# Telegraph Av + Alcatraz Av (37.850465986518, -122.260394000001)
# Telegraph Av + Prince St (37.85362198629, -122.259940000002)
# Telegraph Av + Webster St (37.85511098618, -122.259717000002)
# Telegraph Av:Ashby Av (37.855966986118, -122.259599000001)
# Telegraph Av + Russell St (37.857941985977, -122.259338)
# Telegraph Av + Stuart St (37.859920985833, -122.259027000001)
# Telegraph Av + Derby St (37.861609985712, -122.258818)
# Telegraph Av + Parker St (37.863066985606, -122.258605000001)
# Telegraph Av + Dwight Way (37.864989985468, -122.258364999999)
# Telegraph Av + Haste St (37.866292985373, -122.258609999999)
# Bancroft Way:Telegraph Av (37.868645985204, -122.260255000002)
# Bancroft Way + Dana St (37.868457985217, -122.261913)
# Bancroft Way + Ellsworth St (37.868168985237, -122.264083000001)
# Oxford St:Addison St (37.871341985008, -122.265813)
